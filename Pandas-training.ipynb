# %%
import os
os.listdir("../data/")

import pandas as pd
df = pd.read_csv("../data/athlete_events.csv")
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
print(df.shape)
df.info()
# Out:
# (271116, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df.Sex.value_counts(normalize = True, dropna = False)
# Out:
# M    0.725129
# F    0.274871
# Name: Sex, dtype: float64

# %%
type(df.sort_values(by = ['Age', 'Name'], inplace = True))
# Out:
# NoneType

# %%
df.head(5)
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 142882   71691               Dimitrios Loundras   M  10.0     NaN     NaN
# 101378   51268                   Beatrice Hutiu   F  11.0   151.0    38.0
# 73461    37333  Carlos Bienvenido Front Barrera   M  11.0     NaN     NaN
# 102916   52070                     Etsuko Inada   F  11.0     NaN     NaN
# 252230  126307                     Liana Vicens   F  11.0   158.0    50.0
#
#                                  Team  NOC        Games  Year  Season  \
# 142882  Ethnikos Gymnastikos Syllogos  GRE  1896 Summer  1896  Summer
# 101378                        Romania  ROU  1968 Winter  1968  Winter
# 73461                           Spain  ESP  1992 Summer  1992  Summer
# 102916                          Japan  JPN  1936 Winter  1936  Winter
# 252230                    Puerto Rico  PUR  1968 Summer  1968  Summer
#
#                           City           Sport  \
# 142882                  Athina      Gymnastics
# ...

# %%
df[(df.Name.str.contains("(?i)jesse")) & (df.Name.str.contains("(?i)owen"))]['Games'].drop_duplicates()
# Out:
# 179557    1936 Summer
# Name: Games, dtype: object

# %%
df.value_counts("Medal")
# Out:
# Medal
# Gold      13372
# Bronze    13295
# Silver    13116
# dtype: int64

# %%
df[(df["Medal"] == "Gold") & (df["Sex"] == "M") ].value_counts("Team", ascending = False)
# Out:
# Team
# United States                  1644
# Soviet Union                    758
# Germany                         476
# Italy                           474
# Great Britain                   424
#                                ...
# Cicely-1                          1
# Colombia                          1
# Cote d'Ivoire                     1
# Individual Olympic Athletes       1
# Fantlet-7                         1
# Length: 227, dtype: int64

# %%
df[(df["Medal"] == "Gold") & (df["Sex"] == "M") ].sort_values("Team")[['Team', 'Games']]
# Out:
#                                 Team        Games
# 147152                       Algeria  2012 Summer
# 163052                       Algeria  1996 Summer
# 224926                       Algeria  1996 Summer
# 19197   Amateur Athletic Association  1900 Summer
# 202022  Amateur Athletic Association  1900 Summer
# ...                              ...          ...
# 270388                    Yugoslavia  1972 Summer
# 197840                    Yugoslavia  1988 Summer
# 127235                    Yugoslavia  1984 Summer
# 231849                    Yugoslavia  1984 Summer
# 142122                    Yugoslavia  1968 Summer
#
# [9625 rows x 2 columns]
